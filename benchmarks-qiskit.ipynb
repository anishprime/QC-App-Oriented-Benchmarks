# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - Qiskit Version
# The notebook contains a suite of application-oriented benchmarks for the Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one benchmark program.

# %%
min_qubits=4
max_qubits=4
skip_qubits=1
max_circuits=1
num_shots=1000

backend_id="qasm_simulator"
#backend_id="statevector_simulator"

hub=""; group=""; project=""
provider_backend = None

from qiskit.circuit import QuantumCircuit, QuantumRegister, ClassicalRegister, IfElseOp
from qiskit.circuit.classical import expr
from qiskit.transpiler import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2

# # ==========================
# # *** If using IBM Quantum hardware, run this once to authenticate
from qiskit_ibm_runtime import QiskitRuntimeService
QiskitRuntimeService.save_account(instance = "crn:v1:bluemix:public:quantum-computing:us-east:a/de6d20e9c7634fedb76790a0acfdf790:7944cbc6-135f-42f1-8312-06ed2bf350f8::", token = 'avYu3rZgj0U2z8wwvuyvGALyZi9mwwd1F1krkUYGaTAx', overwrite=True)  # only need to do this first time
#
# QiskitRuntimeService.save_account('iJwfYvWNNeZG_iMNcWb6ck5LohM3RRnmmgN5C0RtRDIh')
# # *** If you use `ibm_quantum` channel, set hub, group, and project name here
# hub="YOUR_HUB_NAME"; group="YOUR_GROUP_NAME"; project="YOUR_PROJECT_NAME"

# # *** If you use `ibm_cloud` channel, set hub, group, and project name here
hub=""; group=""; project="crn:v1:bluemix:public:quantum-computing:us-east:a/de6d20e9c7634fedb76790a0acfdf790:7944cbc6-135f-42f1-8312-06ed2bf350f8::"

# *** This example shows how to specify an IBMQ backend using a known "backend_id"
#     See the App-Oriented Benchmarks setup page documentation for more info ob backends and options. 
exec_options = {
    "use_ibm_quantum_platform": False,
    "use_sessions": False,
    "dynamic_circuit": True,            #Use Mid circuit measurements
    "dynamical_decoupling": True,       #Use DD 
}

# service = QiskitRuntimeService()# backend_id="ibm_fez"
# backend = service.backend("ibm_marrakesh")

backend_id="ibm_pittsburgh"
# # ==========================
# # *** If using Azure Quantum, use this hub identifier and specify the desired backend_id
# # Identify your resources with env variables AZURE_QUANTUM_RESOURCE_ID and AZURE_QUANTUM_LOCATION
# hub="azure-quantum"; group="open"; project="QED-C App-Oriented Benchmarks - Qiskit Version"
# backend_id="<YOUR_BACKEND_NAME_HERE>"

# # ==========================
# The remaining examples illustrate other backend execution options

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # An example using BlueQubit provider (backend_id=CPU/QPU, device=cpu/qpu)
# import os, bluequbit, _common.executors.bluequbit_executor as bluequbit_executor
# provider_backend = bluequbit.init()
# backend_id="BlueQubit-CPU"
# exec_options = { "executor": bluequbit_executor.run, "device":"cpu" }

# # An example using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# # Fire Opal can be used to manage executions on other backends, as illustrated here
# import _common.executors.fire_opal_executor as fire_opal_executor
# from _common.executors.fire_opal_executor import FireOpalBackend
# ibm_backend_id = "ibmq_jakarta"
# backend_id = f"fire_opal_{ibm_backend_id}"
# provider_backend = FireOpalBackend(ibm_backend_id=ibm_backend_id, hub=hub, group=group, project=project, token=token)
# exec_options = {"executor": fire_opal_executor.run}

# %%
# Custom optimization options can be specified in this cell (below is an example)

# # Example of pytket Transformer
# import _common.transformers.tket_optimiser as tket_optimiser
# exec_options.update({ "optimization_level": 0, "layout_method":'sabre', "routing_method":'sabre', "transformer": tket_optimiser.high_optimisation })

# # Define a custom noise model to be used during execution
# import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
# exec_options.update({ "noise_model": custom_qiskit_noise_model.my_noise_model() })

# # Example of mthree error mitigation
# import _common.postprocessors.mthree.mthree_em as mthree_em
# exec_options.update({ "postprocessor": mthree_em.get_mthree_handlers(backend_id, provider_backend) })

# %% [markdown]
# ### Deutsch-Jozsa

# %%
import sys
sys.path.insert(1, "deutsch-jozsa")
import dj_benchmark
dj_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
import sys
sys.path.insert(1, "bernstein-vazirani")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Bernstein-Vazirani - Method 2

# %%
import sys
sys.path.insert(1, "bernstein-vazirani")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Hidden Shift

# %%
import sys
sys.path.insert(1, "hidden-shift")
import hs_benchmark
hs_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform")


import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1, use_midcircuit_measurement = True,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform (1) Benchmark Program - Qiskit
# ... execution starting at Sep 27, 2025 02:59:59 UTC
# ... using Qiskit Runtime channel='ibm_cloud' instance='crn:v1:bluemix:public:quantum-computing:us-east:a/de6d20e9c7634fedb76790a0acfdf790:7944cbc6-135f-42f1-8312-06ed2bf350f8::'
# ... using backend=<IBMBackend('ibm_fez')> primitive_name='sampler'
# ... execute using Sampler on backend_name='ibm_fez' with options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=Unset, sequence_type=Unset, extra_slack_distribution=Unset, scheduling_method=Unset, skip_reset_qubits=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=Unset, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=Unset, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [1] circuits with num_qubits = 4
# /home/cudaq/.local/lib/python3.10/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:1102: UserWarning: The backend ibm_fez currently has a status of internal.
#   warnings.warn(

# %% [markdown]
# ### Quantum Fourier Transform - Method 2

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=2, use_midcircuit_measurement = exec_options.get("dynamic_circuit"),
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Grover

# %%
import sys
sys.path.insert(1, "grovers")
import grovers_benchmark
grovers_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Phase Estimation

# %%
import sys
sys.path.insert(1, "phase-estimation")
import pe_benchmark
pe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots, use_midcircuit_measurement = exec_options.get("dynamic_circuit"), 
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Phase Estimation Benchmark Program - Qiskit
# ... execution starting at Aug 11, 2025 14:35:24 UTC
# ... using Qiskit Runtime channel='ibm_cloud' instance='crn:v1:bluemix:public:quantum-computing:us-east:a/1d194ddd99a94496b8f253cb72212526:6f07487f-bcc0-435e-a042-3def311b8213::'
# 1. code reached if_else add
# ... using backend=<IBMBackend('ibm_fez')> primitive_name='sampler'
# ... execute using Sampler on backend_name='ibm_fez' with options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=Unset, sequence_type=Unset, extra_slack_distribution=Unset, scheduling_method=Unset, skip_reset_qubits=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=Unset, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=Unset, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [3] circuits with num_qubits = 3
# algorithmic cirq depth: 15
# 2. code reached pm generate pass manager
# trans_qc: global phase: 13π/8
#             ┌─────────┐┌────┐┌─────────┐ ░ ┌─────────┐┌──────────────┐»
# q0_1 -> 136 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(π/4) ├┤ Delay(6[dt]) ├»
#             ├─────────┤├────┤├─────────┤ ░ ├─────────┤└────┬───┬─────┘»
# q0_0 -> 142 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(π/2) ├─────┤ X ├──────»
#             └──┬───┬──┘└────┘└─────────┘ ░ ├─────────┤     ├───┴┐     »
# q0_2 -> 143 ───┤ X ├─────────────────────░─┤ Rz(π/2) ├─────┤ √X ├─────»
#                └───┘                     ░ └─────────┘     └────┘     »
#       c0: 2/══════════════════════════════════════════════════════════»
#                                                                       »
# «                                     ┌───────────────┐                   »
# «q0_1 -> 136 ───────────────────────■─┤ Delay(12[dt]) ├───────────────────»
# «            ┌───────────────┐┌───┐ │ └┬──────────────┤                   »
# «q0_0 -> 142 ┤ Delay(48[dt]) ├┤ X ├─┼──┤ Delay(4[dt]) ├───────────────────»
# «            └──┬─────────┬──┘└───┘ │  └─┬──────────┬─┘┌────┐┌───────────┐»
# «q0_2 -> 143 ───┤ Rz(π/2) ├─────────■────┤ Rz(-π/2) ├──┤ √X ├┤ Rz(-3π/4) ├»
# «               └─────────┘              └──────────┘  └────┘└───────────┘»
# «      c0: 2/═════════════════════════════════════════════════════════════»
# «                                                                         »
# «                                    ┌───┐   ┌───────────────┐    ┌───┐    »
# «q0_1 -> 136 ───────────────────■────┤ X ├───┤ Delay(32[dt]) ├────┤ X ├────»
# «                               │    └───┘   └───────────────┘    └───┘    »
# «q0_0 -> 142 ───────────────────┼──────────────────────────────────────────»
# «            ┌────┐┌──────────┐ │ ┌─────────┐      ┌────┐     ┌───────────┐»
# «q0_2 -> 143 ┤ √X ├┤ Rz(-π/2) ├─■─┤ Rz(π/2) ├──────┤ √X ├─────┤ Rz(-3π/4) ├»
# «            └────┘└──────────┘   └─────────┘      └────┘     └───────────┘»
# «      c0: 2/══════════════════════════════════════════════════════════════»
# «                                                                          »
# «            ┌───────────────┐                                                 »
# «q0_1 -> 136 ┤ Delay(14[dt]) ├─────────────────────────────────────────────────»
# «            └───────────────┘              ┌──────────────┐                   »
# «q0_0 -> 142 ─────────────────────────────■─┤ Delay(6[dt]) ├─────────────────■─»
# «                  ┌────┐     ┌─────────┐ │ └──┬────────┬──┘┌────┐┌────────┐ │ »
# «q0_2 -> 143 ──────┤ √X ├─────┤ Rz(π/2) ├─■────┤ Rz(-π) ├───┤ √X ├┤ Rz(-π) ├─■─»
# «                  └────┘     └─────────┘      └────────┘   └────┘└────────┘   »
# «      c0: 2/══════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                             ░ ┌────────────────┐┌───┐ »
# «q0_1 -> 136 ─────────────────────────────────░─┤ Delay(144[dt]) ├┤ X ├─»
# «            ┌──────────────┐                 ░ └──┬─────────┬───┘├───┴┐»
# «q0_0 -> 142 ┤ Delay(6[dt]) ├─────────────────░────┤ Rz(π/2) ├────┤ √X ├»
# «            └─┬─────────┬──┘┌────┐┌────────┐ ░ ┌──┴─────────┴───┐├───┬┘»
# «q0_2 -> 143 ──┤ Rz(π/2) ├───┤ √X ├┤ Rz(-π) ├─░─┤ Delay(144[dt]) ├┤ X ├─»
# «              └─────────┘   └────┘└────────┘ ░ └────────────────┘└───┘ »
# «      c0: 2/═══════════════════════════════════════════════════════════»
# «                                                                       »
# «            ┌────────────────┐┌───┐┌────────────────┐                   ░ »
# «q0_1 -> 136 ┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├───────────────────░─»
# «            └──┬─────────┬───┘└───┘└──────┬─┬───────┘                   ░ »
# «q0_0 -> 142 ───┤ Rz(π/2) ├────────────────┤M├───────────────────────────░─»
# «            ┌──┴─────────┴───┐┌───┐       └╥┘        ┌────────────────┐ ░ »
# «q0_2 -> 143 ┤ Delay(320[dt]) ├┤ X ├────────╫─────────┤ Delay(144[dt]) ├─░─»
# «            └────────────────┘└───┘        ║         └────────────────┘ ░ »
# «      c0: 2/═══════════════════════════════╩══════════════════════════════»
# «                                           0                              »
# «              ┌──────   ┌──────────┐ ───────┐  ░         ░         »
# «q0_1 -> 136 ──┤       ──┤ Rz(-π/2) ├        ├──░─────────░─────────»
# «              │         └──────────┘        │  ░         ░         »
# «q0_0 -> 142 ──┤ If-0  ──────────────  End-0 ├──░─────────░─────────»
# «              │                             │  ░ ┌────────────────┐»
# «q0_2 -> 143 ──┤       ──────────────        ├──░─┤ Delay(144[dt]) ├»
# «              └──╥───                ───────┘  ░ └────────────────┘»
# «            ┌────╨─────┐                                           »
# «      c0: 2/╡ c0_0=0x1 ╞═══════════════════════════════════════════»
# «            └──────────┘                                           »
# «               ┌─────────┐          ┌────┐         ┌─────────┐    »
# «q0_1 -> 136 ───┤ Rz(π/2) ├──────────┤ √X ├─────────┤ Rz(π/2) ├────»
# «            ┌──┴─────────┴───┐      ├───┬┘      ┌──┴─────────┴───┐»
# «q0_0 -> 142 ┤ Delay(144[dt]) ├──────┤ X ├───────┤ Delay(320[dt]) ├»
# «            └─────┬───┬──────┘┌─────┴───┴──────┐└─────┬───┬──────┘»
# «q0_2 -> 143 ──────┤ X ├───────┤ Delay(320[dt]) ├──────┤ X ├───────»
# «                  └───┘       └────────────────┘      └───┘       »
# «      c0: 2/══════════════════════════════════════════════════════»
# «                                                                  »
# «                              ┌─┐                   ░  ░
# «q0_1 -> 136 ──────────────────┤M├───────────────────░──░─
# «                  ┌───┐       └╥┘┌────────────────┐ ░  ░
# «q0_0 -> 142 ──────┤ X ├────────╫─┤ Delay(144[dt]) ├─░──░─
# «            ┌─────┴───┴──────┐ ║ └────────────────┘ ░  ░
# «q0_2 -> 143 ┤ Delay(144[dt]) ├─╫───────────────────────░─
# «            └────────────────┘ ║                       ░
# «      c0: 2/═══════════════════╩═════════════════════════
# «                               1
# transpiled normalized cirq depth: 37
# 4. Sampler is called correctly
# algorithmic cirq depth: 15
# 2. code reached pm generate pass manager
# trans_qc: global phase: π/4
#             ┌─────────┐┌────┐┌─────────┐ ░ ┌─────────┐┌──────────────┐»
# q1_1 -> 136 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(π/2) ├┤ Delay(6[dt]) ├»
#             ├─────────┤├────┤├─────────┤ ░ └┬───────┬┘└────┬───┬─────┘»
# q1_0 -> 142 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░──┤ Rz(π) ├──────┤ X ├──────»
#             └──┬───┬──┘└────┘└─────────┘ ░ ┌┴───────┴┐     ├───┴┐     »
# q1_2 -> 143 ───┤ X ├─────────────────────░─┤ Rz(π/2) ├─────┤ √X ├─────»
#                └───┘                     ░ └─────────┘     └────┘     »
#       c0: 2/══════════════════════════════════════════════════════════»
#                                                                       »
# «                                     ┌──────────────┐                   ┌───┐ »
# «q1_1 -> 136 ───────────────────────■─┤ Delay(6[dt]) ├─────────────────■─┤ X ├─»
# «            ┌───────────────┐┌───┐ │ ├──────────────┤                 │ └───┘ »
# «q1_0 -> 142 ┤ Delay(32[dt]) ├┤ X ├─┼─┤ Delay(8[dt]) ├─────────────────┼───────»
# «            └──┬─────────┬──┘└───┘ │ └──┬────────┬──┘┌────┐┌────────┐ │ ┌────┐»
# «q1_2 -> 143 ───┤ Rz(π/2) ├─────────■────┤ Rz(-π) ├───┤ √X ├┤ Rz(-π) ├─■─┤ √X ├»
# «               └─────────┘              └────────┘   └────┘└────────┘   └────┘»
# «      c0: 2/══════════════════════════════════════════════════════════════════»
# «                                                                              »
# «            ┌───────────────┐     ┌───┐      ┌──────────────┐                »
# «q1_1 -> 136 ┤ Delay(32[dt]) ├─────┤ X ├──────┤ Delay(8[dt]) ├────────────────»
# «            └───────────────┘┌────┴───┴─────┐└──────────────┘┌──────────────┐»
# «q1_0 -> 142 ────────■────────┤ Delay(6[dt]) ├───────■────────┤ Delay(6[dt]) ├»
# «                    │        └────┬───┬─────┘       │        └─┬─────────┬──┘»
# «q1_2 -> 143 ────────■─────────────┤ X ├─────────────■──────────┤ Rz(π/2) ├───»
# «                                  └───┘                        └─────────┘   »
# «      c0: 2/═════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                               ░ ┌────────────────┐┌───┐ ┌────────────────┐»
# «q1_1 -> 136 ───────────────────░─┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├»
# «                               ░ └──┬─────────┬───┘├───┴┐└──┬─────────┬───┘»
# «q1_0 -> 142 ───────────────────░────┤ Rz(π/2) ├────┤ √X ├───┤ Rz(π/2) ├────»
# «            ┌────┐┌──────────┐ ░ ┌──┴─────────┴───┐├───┬┘┌──┴─────────┴───┐»
# «q1_2 -> 143 ┤ √X ├┤ Rz(-π/2) ├─░─┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├»
# «            └────┘└──────────┘ ░ └────────────────┘└───┘ └────────────────┘»
# «      c0: 2/═══════════════════════════════════════════════════════════════»
# «                                                                           »
# «            ┌───┐┌────────────────┐                   ░   ┌──────   »
# «q1_1 -> 136 ┤ X ├┤ Delay(144[dt]) ├───────────────────░───┤       ──»
# «            └───┘└──────┬─┬───────┘                   ░   │         »
# «q1_0 -> 142 ────────────┤M├───────────────────────────░───┤ If-0  ──»
# «            ┌───┐       └╥┘        ┌────────────────┐ ░   │         »
# «q1_2 -> 143 ┤ X ├────────╫─────────┤ Delay(144[dt]) ├─░───┤       ──»
# «            └───┘        ║         └────────────────┘ ░   └──╥───   »
# «                         ║                              ┌────╨─────┐»
# «      c0: 2/═════════════╩══════════════════════════════╡ c0_0=0x1 ╞»
# «                         0                              └──────────┘»
# «            ┌──────────┐ ───────┐  ░         ░            ┌─────────┐    »
# «q1_1 -> 136 ┤ Rz(-π/2) ├        ├──░─────────░────────────┤ Rz(π/2) ├────»
# «            └──────────┘        │  ░         ░         ┌──┴─────────┴───┐»
# «q1_0 -> 142 ────────────  End-0 ├──░─────────░─────────┤ Delay(144[dt]) ├»
# «                                │  ░ ┌────────────────┐└─────┬───┬──────┘»
# «q1_2 -> 143 ────────────        ├──░─┤ Delay(144[dt]) ├──────┤ X ├───────»
# «                         ───────┘  ░ └────────────────┘      └───┘       »
# «      c0: 2/═════════════════════════════════════════════════════════════»
# «                                                                         »
# «                  ┌────┐         ┌─────────┐                      ┌─┐»
# «q1_1 -> 136 ──────┤ √X ├─────────┤ Rz(π/2) ├──────────────────────┤M├»
# «                  ├───┬┘      ┌──┴─────────┴───┐      ┌───┐       └╥┘»
# «q1_0 -> 142 ──────┤ X ├───────┤ Delay(320[dt]) ├──────┤ X ├────────╫─»
# «            ┌─────┴───┴──────┐└─────┬───┬──────┘┌─────┴───┴──────┐ ║ »
# «q1_2 -> 143 ┤ Delay(320[dt]) ├──────┤ X ├───────┤ Delay(144[dt]) ├─╫─»
# «            └────────────────┘      └───┘       └────────────────┘ ║ »
# «      c0: 2/═══════════════════════════════════════════════════════╩═»
# «                                                                   1 »
# «                               ░  ░
# «q1_1 -> 136 ───────────────────░──░─
# «            ┌────────────────┐ ░  ░
# «q1_0 -> 142 ┤ Delay(144[dt]) ├─░──░─
# «            └────────────────┘ ░  ░
# «q1_2 -> 143 ──────────────────────░─
# «                                  ░
# «      c0: 2/════════════════════════
# «
# transpiled normalized cirq depth: 29
# 4. Sampler is called correctly
# algorithmic cirq depth: 15
# 2. code reached pm generate pass manager
# trans_qc: global phase: 3π/8
#             ┌─────────┐┌────┐┌─────────┐ ░ ┌──────────┐┌──────────────┐»
# q2_1 -> 136 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(3π/4) ├┤ Delay(6[dt]) ├»
#             ├─────────┤├────┤├─────────┤ ░ ├──────────┤└────┬───┬─────┘»
# q2_0 -> 142 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(3π/2) ├─────┤ X ├──────»
#             └──┬───┬──┘└────┘└─────────┘ ░ ├─────────┬┘     ├───┴┐     »
# q2_2 -> 143 ───┤ X ├─────────────────────░─┤ Rz(π/2) ├──────┤ √X ├─────»
#                └───┘                     ░ └─────────┘      └────┘     »
#       c0: 2/═══════════════════════════════════════════════════════════»
#                                                                        »
# «                                     ┌───────────────┐                        »
# «q2_1 -> 136 ───────────────────────■─┤ Delay(12[dt]) ├────────────────────────»
# «            ┌───────────────┐┌───┐ │ └┬──────────────┤                        »
# «q2_0 -> 142 ┤ Delay(48[dt]) ├┤ X ├─┼──┤ Delay(4[dt]) ├────────────────────────»
# «            └──┬─────────┬──┘└───┘ │  └─┬──────────┬─┘┌────┐┌──────────┐┌────┐»
# «q2_2 -> 143 ───┤ Rz(π/2) ├─────────■────┤ Rz(-π/2) ├──┤ √X ├┤ Rz(-π/4) ├┤ √X ├»
# «               └─────────┘              └──────────┘  └────┘└──────────┘└────┘»
# «      c0: 2/══════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                              ┌───┐   ┌───────────────┐   ┌───┐    »
# «q2_1 -> 136 ─────────────■────┤ X ├───┤ Delay(32[dt]) ├───┤ X ├────»
# «                         │    └───┘   └───────────────┘   └───┘    »
# «q2_0 -> 142 ─────────────┼─────────────────────────────────────────»
# «            ┌──────────┐ │ ┌─────────┐      ┌────┐     ┌──────────┐»
# «q2_2 -> 143 ┤ Rz(-π/2) ├─■─┤ Rz(π/2) ├──────┤ √X ├─────┤ Rz(-π/4) ├»
# «            └──────────┘   └─────────┘      └────┘     └──────────┘»
# «      c0: 2/═══════════════════════════════════════════════════════»
# «                                                                   »
# «            ┌───────────────┐                                                 »
# «q2_1 -> 136 ┤ Delay(14[dt]) ├─────────────────────────────────────────────────»
# «            └───────────────┘              ┌──────────────┐   ┌──────────────┐»
# «q2_0 -> 142 ─────────────────────────────■─┤ Delay(6[dt]) ├─■─┤ Delay(6[dt]) ├»
# «                  ┌────┐     ┌─────────┐ │ └────┬────┬────┘ │ └─┬─────────┬──┘»
# «q2_2 -> 143 ──────┤ √X ├─────┤ Rz(π/2) ├─■──────┤ √X ├──────■───┤ Rz(π/2) ├───»
# «                  └────┘     └─────────┘        └────┘          └─────────┘   »
# «      c0: 2/══════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                   ░ ┌────────────────┐┌───┐ ┌────────────────┐┌───┐»
# «q2_1 -> 136 ───────░─┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├»
# «                   ░ └──┬─────────┬───┘├───┴┐└──┬─────────┬───┘└───┘»
# «q2_0 -> 142 ───────░────┤ Rz(π/2) ├────┤ √X ├───┤ Rz(π/2) ├─────────»
# «            ┌────┐ ░ ┌──┴─────────┴───┐├───┬┘┌──┴─────────┴───┐┌───┐»
# «q2_2 -> 143 ┤ √X ├─░─┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├»
# «            └────┘ ░ └────────────────┘└───┘ └────────────────┘└───┘»
# «      c0: 2/════════════════════════════════════════════════════════»
# «                                                                    »
# «            ┌────────────────┐                   ░   ┌──────   ┌──────────┐»
# «q2_1 -> 136 ┤ Delay(144[dt]) ├───────────────────░───┤       ──┤ Rz(-π/2) ├»
# «            └──────┬─┬───────┘                   ░   │         └──────────┘»
# «q2_0 -> 142 ───────┤M├───────────────────────────░───┤ If-0  ──────────────»
# «                   └╥┘        ┌────────────────┐ ░   │                     »
# «q2_2 -> 143 ────────╫─────────┤ Delay(144[dt]) ├─░───┤       ──────────────»
# «                    ║         └────────────────┘ ░   └──╥───               »
# «                    ║                              ┌────╨─────┐            »
# «      c0: 2/════════╩══════════════════════════════╡ c0_0=0x1 ╞════════════»
# «                    0                              └──────────┘            »
# «             ───────┐  ░         ░            ┌─────────┐    »
# «q2_1 -> 136         ├──░─────────░────────────┤ Rz(π/2) ├────»
# «                    │  ░         ░         ┌──┴─────────┴───┐»
# «q2_0 -> 142   End-0 ├──░─────────░─────────┤ Delay(144[dt]) ├»
# «                    │  ░ ┌────────────────┐└─────┬───┬──────┘»
# «q2_2 -> 143         ├──░─┤ Delay(144[dt]) ├──────┤ X ├───────»
# «             ───────┘  ░ └────────────────┘      └───┘       »
# «      c0: 2/═════════════════════════════════════════════════»
# «                                                             »
# «                  ┌────┐         ┌─────────┐                      ┌─┐»
# «q2_1 -> 136 ──────┤ √X ├─────────┤ Rz(π/2) ├──────────────────────┤M├»
# «                  ├───┬┘      ┌──┴─────────┴───┐      ┌───┐       └╥┘»
# «q2_0 -> 142 ──────┤ X ├───────┤ Delay(320[dt]) ├──────┤ X ├────────╫─»
# «            ┌─────┴───┴──────┐└─────┬───┬──────┘┌─────┴───┴──────┐ ║ »
# «q2_2 -> 143 ┤ Delay(320[dt]) ├──────┤ X ├───────┤ Delay(144[dt]) ├─╫─»
# «            └────────────────┘      └───┘       └────────────────┘ ║ »
# «      c0: 2/═══════════════════════════════════════════════════════╩═»
# «                                                                   1 »
# «                               ░  ░
# «q2_1 -> 136 ───────────────────░──░─
# «            ┌────────────────┐ ░  ░
# «q2_0 -> 142 ┤ Delay(144[dt]) ├─░──░─
# «            └────────────────┘ ░  ░
# «q2_2 -> 143 ──────────────────────░─
# «                                  ░
# «      c0: 2/════════════════════════
# «
# transpiled normalized cirq depth: 34
# 4. Sampler is called correctly
# ************
# Executing [3] circuits with num_qubits = 4
# algorithmic cirq depth: 23
# 2. code reached pm generate pass manager
# trans_qc: global phase: 3π/16
#             ┌─────────┐┌────┐┌─────────┐ ░ ┌─────────┐ ┌──────────────┐»
# q3_2 -> 136 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(π/8) ├─┤ Delay(6[dt]) ├»
#             ├─────────┤├────┤├─────────┤ ░ ├─────────┤ └────┬───┬─────┘»
# q3_1 -> 142 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(π/4) ├──────┤ X ├──────»
#             └──┬───┬──┘└────┘└─────────┘ ░ ├─────────┤      ├───┴┐     »
# q3_3 -> 143 ───┤ X ├─────────────────────░─┤ Rz(π/2) ├──────┤ √X ├─────»
#             ┌──┴───┴──┐┌────┐┌─────────┐ ░ ├─────────┤┌─────┴────┴────┐»
# q3_0 -> 144 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(π/2) ├┤ Delay(16[dt]) ├»
#             └─────────┘└────┘└─────────┘ ░ └─────────┘└───────────────┘»
#       c0: 3/═══════════════════════════════════════════════════════════»
#                                                                        »
# «                                                   ┌───────────────┐      »
# «q3_2 -> 136 ────────────────────────────────────■──┤ Delay(12[dt]) ├──────»
# «            ┌───────────────┐      ┌───┐        │  └┬──────────────┤      »
# «q3_1 -> 142 ┤ Delay(48[dt]) ├──────┤ X ├────────┼───┤ Delay(4[dt]) ├──────»
# «            └──┬─────────┬──┘      └───┘        │   └─┬──────────┬─┘┌────┐»
# «q3_3 -> 143 ───┤ Rz(π/2) ├──────────────────────■─────┤ Rz(-π/2) ├──┤ √X ├»
# «               └──┬───┬──┘   ┌───────────────┐┌───┐┌──┴──────────┴─┐└────┘»
# «q3_0 -> 144 ──────┤ X ├──────┤ Delay(64[dt]) ├┤ X ├┤ Delay(30[dt]) ├──────»
# «                  └───┘      └───────────────┘└───┘└───────────────┘      »
# «      c0: 3/══════════════════════════════════════════════════════════════»
# «                                                                          »
# «                                              ┌───────────────┐┌───┐ »
# «q3_2 -> 136 ────────────────────────────────■─┤ Delay(16[dt]) ├┤ X ├─»
# «                                            │ └───────────────┘└───┘ »
# «q3_1 -> 142 ────────────────────────────────┼────────────────────────»
# «            ┌───────────┐┌────┐┌──────────┐ │    ┌─────────┐   ┌────┐»
# «q3_3 -> 143 ┤ Rz(-7π/8) ├┤ √X ├┤ Rz(-π/2) ├─■────┤ Rz(π/2) ├───┤ √X ├»
# «            └───────────┘└────┘└──────────┘      └─────────┘   └────┘»
# «q3_0 -> 144 ─────────────────────────────────────────────────────────»
# «                                                                     »
# «      c0: 3/═════════════════════════════════════════════════════════»
# «                                                                     »
# «            ┌───────────────┐┌───┐ ┌───────────────┐                          »
# «q3_2 -> 136 ┤ Delay(64[dt]) ├┤ X ├─┤ Delay(24[dt]) ├──────────────────────────»
# «            └───────────────┘└───┘ └───────────────┘   ┌───────────────┐      »
# «q3_1 -> 142 ─────────────────────────────────────────■─┤ Delay(12[dt]) ├──────»
# «              ┌───────────┐  ┌────┐   ┌─────────┐    │ └──┬──────────┬─┘┌────┐»
# «q3_3 -> 143 ──┤ Rz(-7π/8) ├──┤ √X ├───┤ Rz(π/2) ├────■────┤ Rz(-π/2) ├──┤ √X ├»
# «              └───────────┘  └────┘   └─────────┘         └──────────┘  └────┘»
# «q3_0 -> 144 ──────────────────────────────────────────────────────────────────»
# «                                                                              »
# «      c0: 3/══════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                                          »
# «q3_2 -> 136 ──────────────────────────────────────────────────────────────»
# «                                                 ┌───┐   ┌───────────────┐»
# «q3_1 -> 142 ────────────────────────────────■────┤ X ├───┤ Delay(32[dt]) ├»
# «            ┌───────────┐┌────┐┌──────────┐ │ ┌──┴───┴──┐└─────┬────┬────┘»
# «q3_3 -> 143 ┤ Rz(-3π/4) ├┤ √X ├┤ Rz(-π/2) ├─■─┤ Rz(π/2) ├──────┤ √X ├─────»
# «            └───────────┘└────┘└──────────┘   └─────────┘      └────┘     »
# «q3_0 -> 144 ──────────────────────────────────────────────────────────────»
# «                                                                          »
# «      c0: 3/══════════════════════════════════════════════════════════════»
# «                                                                          »
# «                                                                              »
# «q3_2 -> 136 ──────────────────────────────────────────────────────────────────»
# «                ┌───┐    ┌───────────────┐                                    »
# «q3_1 -> 142 ────┤ X ├────┤ Delay(14[dt]) ├────────────────────────────────────»
# «            ┌───┴───┴───┐└─────┬────┬────┘┌─────────┐      ┌────────┐   ┌────┐»
# «q3_3 -> 143 ┤ Rz(-3π/4) ├──────┤ √X ├─────┤ Rz(π/2) ├─■────┤ Rz(-π) ├───┤ √X ├»
# «            └───────────┘      └────┘     └─────────┘ │ ┌──┴────────┴──┐└────┘»
# «q3_0 -> 144 ──────────────────────────────────────────■─┤ Delay(6[dt]) ├──────»
# «                                                        └──────────────┘      »
# «      c0: 3/══════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                          ░ ┌────────────────┐»
# «q3_2 -> 136 ──────────────────────────────────────────────░─┤ Delay(144[dt]) ├»
# «                                                          ░ ├────────────────┤»
# «q3_1 -> 142 ──────────────────────────────────────────────░─┤ Delay(144[dt]) ├»
# «            ┌────────┐     ┌─────────┐   ┌────┐┌────────┐ ░ ├────────────────┤»
# «q3_3 -> 143 ┤ Rz(-π) ├─■───┤ Rz(π/2) ├───┤ √X ├┤ Rz(-π) ├─░─┤ Delay(144[dt]) ├»
# «            └────────┘ │ ┌─┴─────────┴──┐└────┘└────────┘ ░ └──┬─────────┬───┘»
# «q3_0 -> 144 ───────────■─┤ Delay(6[dt]) ├─────────────────░────┤ Rz(π/2) ├────»
# «                         └──────────────┘                 ░    └─────────┘    »
# «      c0: 3/══════════════════════════════════════════════════════════════════»
# «                                                                              »
# «            ┌───┐ ┌────────────────┐┌───┐┌────────────────┐ ░   ┌──────   »
# «q3_2 -> 136 ┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─░───┤       ──»
# «            ├───┤ ├────────────────┤├───┤├────────────────┤ ░   │         »
# «q3_1 -> 142 ┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─░───┤       ──»
# «            ├───┤ ├────────────────┤├───┤├────────────────┤ ░   │ If-0    »
# «q3_3 -> 143 ┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─░───┤       ──»
# «            ├───┴┐└──┬─────────┬───┘└┬─┬┘└────────────────┘ ░   │         »
# «q3_0 -> 144 ┤ √X ├───┤ Rz(π/2) ├─────┤M├────────────────────░───┤       ──»
# «            └────┘   └─────────┘     └╥┘                    ░   └──╥───   »
# «                                      ║                       ┌────╨─────┐»
# «      c0: 3/══════════════════════════╩═══════════════════════╡ c0_0=0x1 ╞»
# «                                      0                       └──────────┘»
# «                         ───────┐   ┌──────   ┌──────────┐ ───────┐  ░ »
# «q3_2 -> 136 ────────────        ├───┤       ──┤ Rz(-π/4) ├        ├──░─»
# «            ┌──────────┐        │   │         └──────────┘        │  ░ »
# «q3_1 -> 142 ┤ Rz(-π/2) ├        ├───┤       ──────────────        ├──░─»
# «            └──────────┘  End-0 │   │ If-0                  End-0 │  ░ »
# «q3_3 -> 143 ────────────        ├───┤       ──────────────        ├──░─»
# «                                │   │                             │  ░ »
# «q3_0 -> 144 ────────────        ├───┤       ──────────────        ├──░─»
# «                         ───────┘   └──╥───                ───────┘  ░ »
# «                                  ┌────╨─────┐                         »
# «      c0: 3/══════════════════════╡ c0_0=0x1 ╞═════════════════════════»
# «                                  └──────────┘                         »
# «                               ░ ┌────────────────┐      ┌───┐       »
# «q3_2 -> 136 ───────────────────░─┤ Delay(144[dt]) ├──────┤ X ├───────»
# «                               ░ └──┬─────────┬───┘      ├───┴┐      »
# «q3_1 -> 142 ───────────────────░────┤ Rz(π/2) ├──────────┤ √X ├──────»
# «            ┌────────────────┐ ░    └──┬───┬──┘    ┌─────┴────┴─────┐»
# «q3_3 -> 143 ┤ Delay(144[dt]) ├─────────┤ X ├───────┤ Delay(320[dt]) ├»
# «            └────────────────┘ ░ ┌─────┴───┴──────┐└─────┬───┬──────┘»
# «q3_0 -> 144 ───────────────────░─┤ Delay(144[dt]) ├──────┤ X ├───────»
# «                               ░ └────────────────┘      └───┘       »
# «      c0: 3/═════════════════════════════════════════════════════════»
# «                                                                     »
# «            ┌────────────────┐      ┌───┐       ┌────────────────┐»
# «q3_2 -> 136 ┤ Delay(320[dt]) ├──────┤ X ├───────┤ Delay(144[dt]) ├»
# «            └──┬─────────┬───┘      └───┘       └──────┬─┬───────┘»
# «q3_1 -> 142 ───┤ Rz(π/2) ├─────────────────────────────┤M├────────»
# «               └──┬───┬──┘    ┌────────────────┐       └╥┘        »
# «q3_3 -> 143 ──────┤ X ├───────┤ Delay(144[dt]) ├────────╫─────────»
# «            ┌─────┴───┴──────┐└─────┬───┬──────┘        ║         »
# «q3_0 -> 144 ┤ Delay(320[dt]) ├──────┤ X ├───────────────╫─────────»
# «            └────────────────┘      └───┘               ║         »
# «      c0: 3/════════════════════════════════════════════╩═════════»
# «                                                        1         »
# «                               ░   ┌──────   ┌──────────┐ ───────┐  ░ »
# «q3_2 -> 136 ───────────────────░───┤       ──┤ Rz(-π/2) ├        ├──░─»
# «                               ░   │         └──────────┘        │  ░ »
# «q3_1 -> 142 ───────────────────░───┤       ──────────────        ├──░─»
# «                               ░   │ If-0                  End-0 │  ░ »
# «q3_3 -> 143 ───────────────────░───┤       ──────────────        ├──░─»
# «            ┌────────────────┐ ░   │                             │  ░ »
# «q3_0 -> 144 ┤ Delay(144[dt]) ├─░───┤       ──────────────        ├──░─»
# «            └────────────────┘ ░   └──╥───                ───────┘  ░ »
# «                                 ┌────╨─────┐                         »
# «      c0: 3/═════════════════════╡ c0_1=0x1 ╞═════════════════════════»
# «                                 └──────────┘                         »
# «                               ░    ┌─────────┐          ┌────┐      »
# «q3_2 -> 136 ───────────────────░────┤ Rz(π/2) ├──────────┤ √X ├──────»
# «                               ░ ┌──┴─────────┴───┐      ├───┬┘      »
# «q3_1 -> 142 ───────────────────░─┤ Delay(144[dt]) ├──────┤ X ├───────»
# «            ┌────────────────┐ ░ └─────┬───┬──────┘┌─────┴───┴──────┐»
# «q3_3 -> 143 ┤ Delay(144[dt]) ├─────────┤ X ├───────┤ Delay(320[dt]) ├»
# «            └────────────────┘ ░ ┌─────┴───┴──────┐└─────┬───┬──────┘»
# «q3_0 -> 144 ───────────────────░─┤ Delay(144[dt]) ├──────┤ X ├───────»
# «                               ░ └────────────────┘      └───┘       »
# «      c0: 3/═════════════════════════════════════════════════════════»
# «                                                                     »
# «               ┌─────────┐                      ┌─┐                   ░  ░
# «q3_2 -> 136 ───┤ Rz(π/2) ├──────────────────────┤M├───────────────────░──░─
# «            ┌──┴─────────┴───┐      ┌───┐       └╥┘┌────────────────┐ ░  ░
# «q3_1 -> 142 ┤ Delay(320[dt]) ├──────┤ X ├────────╫─┤ Delay(144[dt]) ├─░──░─
# «            └─────┬───┬──────┘┌─────┴───┴──────┐ ║ └────────────────┘ ░  ░
# «q3_3 -> 143 ──────┤ X ├───────┤ Delay(144[dt]) ├─╫───────────────────────░─
# «            ┌─────┴───┴──────┐└─────┬───┬──────┘ ║ ┌────────────────┐ ░  ░
# «q3_0 -> 144 ┤ Delay(320[dt]) ├──────┤ X ├────────╫─┤ Delay(144[dt]) ├─░──░─
# «            └────────────────┘      └───┘        ║ └────────────────┘ ░  ░
# «      c0: 3/═════════════════════════════════════╩═════════════════════════
# «                                                 2
# transpiled normalized cirq depth: 56
# 4. Sampler is called correctly
# algorithmic cirq depth: 23
# 2. code reached pm generate pass manager
# trans_qc: global phase: 7π/8
#             ┌─────────┐┌────┐┌─────────┐ ░ ┌─────────┐ ┌──────────────┐»
# q4_2 -> 136 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(π/4) ├─┤ Delay(6[dt]) ├»
#             ├─────────┤├────┤├─────────┤ ░ ├─────────┤ └────┬───┬─────┘»
# q4_1 -> 142 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(π/2) ├──────┤ X ├──────»
#             └──┬───┬──┘└────┘└─────────┘ ░ ├─────────┤      ├───┴┐     »
# q4_3 -> 143 ───┤ X ├─────────────────────░─┤ Rz(π/2) ├──────┤ √X ├─────»
#             ┌──┴───┴──┐┌────┐┌─────────┐ ░ └┬───────┬┘┌─────┴────┴────┐»
# q4_0 -> 144 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░──┤ Rz(π) ├─┤ Delay(16[dt]) ├»
#             └─────────┘└────┘└─────────┘ ░  └───────┘ └───────────────┘»
#       c0: 3/═══════════════════════════════════════════════════════════»
#                                                                        »
# «                                                   ┌───────────────┐      »
# «q4_2 -> 136 ────────────────────────────────────■──┤ Delay(12[dt]) ├──────»
# «            ┌───────────────┐      ┌───┐        │  └┬──────────────┤      »
# «q4_1 -> 142 ┤ Delay(48[dt]) ├──────┤ X ├────────┼───┤ Delay(4[dt]) ├──────»
# «            └──┬─────────┬──┘      └───┘        │   └─┬──────────┬─┘┌────┐»
# «q4_3 -> 143 ───┤ Rz(π/2) ├──────────────────────■─────┤ Rz(-π/2) ├──┤ √X ├»
# «               └──┬───┬──┘   ┌───────────────┐┌───┐┌──┴──────────┴─┐└────┘»
# «q4_0 -> 144 ──────┤ X ├──────┤ Delay(64[dt]) ├┤ X ├┤ Delay(18[dt]) ├──────»
# «                  └───┘      └───────────────┘└───┘└───────────────┘      »
# «      c0: 3/══════════════════════════════════════════════════════════════»
# «                                                                          »
# «                                              ┌───────────────┐┌───┐ »
# «q4_2 -> 136 ────────────────────────────────■─┤ Delay(16[dt]) ├┤ X ├─»
# «                                            │ └───────────────┘└───┘ »
# «q4_1 -> 142 ────────────────────────────────┼────────────────────────»
# «            ┌───────────┐┌────┐┌──────────┐ │    ┌─────────┐   ┌────┐»
# «q4_3 -> 143 ┤ Rz(-3π/4) ├┤ √X ├┤ Rz(-π/2) ├─■────┤ Rz(π/2) ├───┤ √X ├»
# «            └───────────┘└────┘└──────────┘      └─────────┘   └────┘»
# «q4_0 -> 144 ─────────────────────────────────────────────────────────»
# «                                                                     »
# «      c0: 3/═════════════════════════════════════════════════════════»
# «                                                                     »
# «            ┌───────────────┐┌───┐ ┌───────────────┐                         »
# «q4_2 -> 136 ┤ Delay(48[dt]) ├┤ X ├─┤ Delay(28[dt]) ├─────────────────────────»
# «            └───────────────┘└───┘ └───────────────┘   ┌──────────────┐      »
# «q4_1 -> 142 ─────────────────────────────────────────■─┤ Delay(6[dt]) ├──────»
# «              ┌───────────┐  ┌────┐   ┌─────────┐    │ └──┬────────┬──┘┌────┐»
# «q4_3 -> 143 ──┤ Rz(-3π/4) ├──┤ √X ├───┤ Rz(π/2) ├────■────┤ Rz(-π) ├───┤ √X ├»
# «              └───────────┘  └────┘   └─────────┘         └────────┘   └────┘»
# «q4_0 -> 144 ─────────────────────────────────────────────────────────────────»
# «                                                                             »
# «      c0: 3/═════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                                                                »
# «q4_2 -> 136 ────────────────────────────────────────────────────»
# «                         ┌───┐ ┌───────────────┐     ┌───┐      »
# «q4_1 -> 142 ───────────■─┤ X ├─┤ Delay(32[dt]) ├─────┤ X ├──────»
# «            ┌────────┐ │ ├───┴┐└───────────────┘     ├───┤      »
# «q4_3 -> 143 ┤ Rz(-π) ├─■─┤ √X ├────────■─────────────┤ X ├──────»
# «            └────────┘   └────┘        │        ┌────┴───┴─────┐»
# «q4_0 -> 144 ───────────────────────────■────────┤ Delay(6[dt]) ├»
# «                                                └──────────────┘»
# «      c0: 3/════════════════════════════════════════════════════»
# «                                                                »
# «                                                               ░ »
# «q4_2 -> 136 ───────────────────────────────────────────────────░─»
# «            ┌──────────────┐                                   ░ »
# «q4_1 -> 142 ┤ Delay(8[dt]) ├───────────────────────────────────░─»
# «            └──────────────┘  ┌─────────┐   ┌────┐┌──────────┐ ░ »
# «q4_3 -> 143 ───────■──────────┤ Rz(π/2) ├───┤ √X ├┤ Rz(-π/2) ├─░─»
# «                   │        ┌─┴─────────┴──┐└────┘└──────────┘ ░ »
# «q4_0 -> 144 ───────■────────┤ Delay(6[dt]) ├───────────────────░─»
# «                            └──────────────┘                   ░ »
# «      c0: 3/═════════════════════════════════════════════════════»
# «                                                                 »
# «            ┌────────────────┐┌───┐ ┌────────────────┐┌───┐┌────────────────┐»
# «q4_2 -> 136 ┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├»
# «            ├────────────────┤├───┤ ├────────────────┤├───┤├────────────────┤»
# «q4_1 -> 142 ┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├»
# «            ├────────────────┤├───┤ ├────────────────┤├───┤├────────────────┤»
# «q4_3 -> 143 ┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├»
# «            └──┬─────────┬───┘├───┴┐└──┬─────────┬───┘└┬─┬┘└────────────────┘»
# «q4_0 -> 144 ───┤ Rz(π/2) ├────┤ √X ├───┤ Rz(π/2) ├─────┤M├───────────────────»
# «               └─────────┘    └────┘   └─────────┘     └╥┘                   »
# «      c0: 3/════════════════════════════════════════════╩════════════════════»
# «                                                        0                    »
# «             ░   ┌──────                ───────┐   ┌──────   ┌──────────┐»
# «q4_2 -> 136 ─░───┤       ──────────────        ├───┤       ──┤ Rz(-π/4) ├»
# «             ░   │         ┌──────────┐        │   │         └──────────┘»
# «q4_1 -> 142 ─░───┤       ──┤ Rz(-π/2) ├        ├───┤       ──────────────»
# «             ░   │ If-0    └──────────┘  End-0 │   │ If-0                »
# «q4_3 -> 143 ─░───┤       ──────────────        ├───┤       ──────────────»
# «             ░   │                             │   │                     »
# «q4_0 -> 144 ─░───┤       ──────────────        ├───┤       ──────────────»
# «             ░   └──╥───                ───────┘   └──╥───               »
# «               ┌────╨─────┐                      ┌────╨─────┐            »
# «      c0: 3/═══╡ c0_0=0x1 ╞══════════════════════╡ c0_0=0x1 ╞════════════»
# «               └──────────┘                      └──────────┘            »
# «             ───────┐  ░                    ░ ┌────────────────┐»
# «q4_2 -> 136         ├──░────────────────────░─┤ Delay(144[dt]) ├»
# «                    │  ░                    ░ └──┬─────────┬───┘»
# «q4_1 -> 142         ├──░────────────────────░────┤ Rz(π/2) ├────»
# «              End-0 │  ░ ┌────────────────┐ ░    └──┬───┬──┘    »
# «q4_3 -> 143         ├──░─┤ Delay(144[dt]) ├─────────┤ X ├───────»
# «                    │  ░ └────────────────┘ ░ ┌─────┴───┴──────┐»
# «q4_0 -> 144         ├──░────────────────────░─┤ Delay(144[dt]) ├»
# «             ───────┘  ░                    ░ └────────────────┘»
# «      c0: 3/════════════════════════════════════════════════════»
# «                                                                »
# «                  ┌───┐       ┌────────────────┐      ┌───┐       »
# «q4_2 -> 136 ──────┤ X ├───────┤ Delay(320[dt]) ├──────┤ X ├───────»
# «                  ├───┴┐      └──┬─────────┬───┘      └───┘       »
# «q4_1 -> 142 ──────┤ √X ├─────────┤ Rz(π/2) ├──────────────────────»
# «            ┌─────┴────┴─────┐   └──┬───┬──┘    ┌────────────────┐»
# «q4_3 -> 143 ┤ Delay(320[dt]) ├──────┤ X ├───────┤ Delay(144[dt]) ├»
# «            └─────┬───┬──────┘┌─────┴───┴──────┐└─────┬───┬──────┘»
# «q4_0 -> 144 ──────┤ X ├───────┤ Delay(320[dt]) ├──────┤ X ├───────»
# «                  └───┘       └────────────────┘      └───┘       »
# «      c0: 3/══════════════════════════════════════════════════════»
# «                                                                  »
# «            ┌────────────────┐                   ░   ┌──────   ┌──────────┐»
# «q4_2 -> 136 ┤ Delay(144[dt]) ├───────────────────░───┤       ──┤ Rz(-π/2) ├»
# «            └──────┬─┬───────┘                   ░   │         └──────────┘»
# «q4_1 -> 142 ───────┤M├───────────────────────────░───┤       ──────────────»
# «                   └╥┘                           ░   │ If-0                »
# «q4_3 -> 143 ────────╫────────────────────────────░───┤       ──────────────»
# «                    ║         ┌────────────────┐ ░   │                     »
# «q4_0 -> 144 ────────╫─────────┤ Delay(144[dt]) ├─░───┤       ──────────────»
# «                    ║         └────────────────┘ ░   └──╥───               »
# «                    ║                              ┌────╨─────┐            »
# «      c0: 3/════════╩══════════════════════════════╡ c0_1=0x1 ╞════════════»
# «                    1                              └──────────┘            »
# «             ───────┐  ░                    ░    ┌─────────┐    »
# «q4_2 -> 136         ├──░────────────────────░────┤ Rz(π/2) ├────»
# «                    │  ░                    ░ ┌──┴─────────┴───┐»
# «q4_1 -> 142         ├──░────────────────────░─┤ Delay(144[dt]) ├»
# «              End-0 │  ░ ┌────────────────┐ ░ └─────┬───┬──────┘»
# «q4_3 -> 143         ├──░─┤ Delay(144[dt]) ├─────────┤ X ├───────»
# «                    │  ░ └────────────────┘ ░ ┌─────┴───┴──────┐»
# «q4_0 -> 144         ├──░────────────────────░─┤ Delay(144[dt]) ├»
# «             ───────┘  ░                    ░ └────────────────┘»
# «      c0: 3/════════════════════════════════════════════════════»
# «                                                                »
# «                  ┌────┐         ┌─────────┐                      ┌─┐»
# «q4_2 -> 136 ──────┤ √X ├─────────┤ Rz(π/2) ├──────────────────────┤M├»
# «                  ├───┬┘      ┌──┴─────────┴───┐      ┌───┐       └╥┘»
# «q4_1 -> 142 ──────┤ X ├───────┤ Delay(320[dt]) ├──────┤ X ├────────╫─»
# «            ┌─────┴───┴──────┐└─────┬───┬──────┘┌─────┴───┴──────┐ ║ »
# «q4_3 -> 143 ┤ Delay(320[dt]) ├──────┤ X ├───────┤ Delay(144[dt]) ├─╫─»
# «            └─────┬───┬──────┘┌─────┴───┴──────┐└─────┬───┬──────┘ ║ »
# «q4_0 -> 144 ──────┤ X ├───────┤ Delay(320[dt]) ├──────┤ X ├────────╫─»
# «                  └───┘       └────────────────┘      └───┘        ║ »
# «      c0: 3/═══════════════════════════════════════════════════════╩═»
# «                                                                   2 »
# «                               ░  ░
# «q4_2 -> 136 ───────────────────░──░─
# «            ┌────────────────┐ ░  ░
# «q4_1 -> 142 ┤ Delay(144[dt]) ├─░──░─
# «            └────────────────┘ ░  ░
# «q4_3 -> 143 ──────────────────────░─
# «            ┌────────────────┐ ░  ░
# «q4_0 -> 144 ┤ Delay(144[dt]) ├─░──░─
# «            └────────────────┘ ░  ░
# «      c0: 3/════════════════════════
# «
# transpiled normalized cirq depth: 48
# 4. Sampler is called correctly
# algorithmic cirq depth: 23
# 2. code reached pm generate pass manager
# trans_qc: global phase: 3.3379
#             ┌─────────┐┌────┐┌─────────┐ ░ ┌──────────┐ ┌──────────────┐»
# q5_2 -> 136 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(3π/8) ├─┤ Delay(6[dt]) ├»
#             ├─────────┤├────┤├─────────┤ ░ ├──────────┤ └────┬───┬─────┘»
# q5_1 -> 142 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(3π/4) ├──────┤ X ├──────»
#             └──┬───┬──┘└────┘└─────────┘ ░ ├─────────┬┘      ├───┴┐     »
# q5_3 -> 143 ───┤ X ├─────────────────────░─┤ Rz(π/2) ├───────┤ √X ├─────»
#             ┌──┴───┴──┐┌────┐┌─────────┐ ░ ├─────────┴┐┌─────┴────┴────┐»
# q5_0 -> 144 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─┤ Rz(3π/2) ├┤ Delay(16[dt]) ├»
#             └─────────┘└────┘└─────────┘ ░ └──────────┘└───────────────┘»
#       c0: 3/════════════════════════════════════════════════════════════»
#                                                                         »
# «                                                   ┌───────────────┐      »
# «q5_2 -> 136 ────────────────────────────────────■──┤ Delay(12[dt]) ├──────»
# «            ┌───────────────┐      ┌───┐        │  └┬──────────────┤      »
# «q5_1 -> 142 ┤ Delay(48[dt]) ├──────┤ X ├────────┼───┤ Delay(4[dt]) ├──────»
# «            └──┬─────────┬──┘      └───┘        │   └─┬──────────┬─┘┌────┐»
# «q5_3 -> 143 ───┤ Rz(π/2) ├──────────────────────■─────┤ Rz(-π/2) ├──┤ √X ├»
# «               └──┬───┬──┘   ┌───────────────┐┌───┐┌──┴──────────┴─┐└────┘»
# «q5_0 -> 144 ──────┤ X ├──────┤ Delay(64[dt]) ├┤ X ├┤ Delay(30[dt]) ├──────»
# «                  └───┘      └───────────────┘└───┘└───────────────┘      »
# «      c0: 3/══════════════════════════════════════════════════════════════»
# «                                                                          »
# «                                              ┌───────────────┐┌───┐ »
# «q5_2 -> 136 ────────────────────────────────■─┤ Delay(16[dt]) ├┤ X ├─»
# «                                            │ └───────────────┘└───┘ »
# «q5_1 -> 142 ────────────────────────────────┼────────────────────────»
# «            ┌───────────┐┌────┐┌──────────┐ │    ┌─────────┐   ┌────┐»
# «q5_3 -> 143 ┤ Rz(-5π/8) ├┤ √X ├┤ Rz(-π/2) ├─■────┤ Rz(π/2) ├───┤ √X ├»
# «            └───────────┘└────┘└──────────┘      └─────────┘   └────┘»
# «q5_0 -> 144 ─────────────────────────────────────────────────────────»
# «                                                                     »
# «      c0: 3/═════════════════════════════════════════════════════════»
# «                                                                     »
# «            ┌───────────────┐┌───┐ ┌───────────────┐                          »
# «q5_2 -> 136 ┤ Delay(64[dt]) ├┤ X ├─┤ Delay(24[dt]) ├──────────────────────────»
# «            └───────────────┘└───┘ └───────────────┘   ┌───────────────┐      »
# «q5_1 -> 142 ─────────────────────────────────────────■─┤ Delay(12[dt]) ├──────»
# «              ┌───────────┐  ┌────┐   ┌─────────┐    │ └──┬──────────┬─┘┌────┐»
# «q5_3 -> 143 ──┤ Rz(-5π/8) ├──┤ √X ├───┤ Rz(π/2) ├────■────┤ Rz(-π/2) ├──┤ √X ├»
# «              └───────────┘  └────┘   └─────────┘         └──────────┘  └────┘»
# «q5_0 -> 144 ──────────────────────────────────────────────────────────────────»
# «                                                                              »
# «      c0: 3/══════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                                         »
# «q5_2 -> 136 ─────────────────────────────────────────────────────────────»
# «                                                ┌───┐   ┌───────────────┐»
# «q5_1 -> 142 ───────────────────────────────■────┤ X ├───┤ Delay(32[dt]) ├»
# «            ┌──────────┐┌────┐┌──────────┐ │ ┌──┴───┴──┐└─────┬────┬────┘»
# «q5_3 -> 143 ┤ Rz(-π/4) ├┤ √X ├┤ Rz(-π/2) ├─■─┤ Rz(π/2) ├──────┤ √X ├─────»
# «            └──────────┘└────┘└──────────┘   └─────────┘      └────┘     »
# «q5_0 -> 144 ─────────────────────────────────────────────────────────────»
# «                                                                         »
# «      c0: 3/═════════════════════════════════════════════════════════════»
# «                                                                         »
# «                                                                          »
# «q5_2 -> 136 ──────────────────────────────────────────────────────────────»
# «               ┌───┐    ┌───────────────┐                                 »
# «q5_1 -> 142 ───┤ X ├────┤ Delay(14[dt]) ├─────────────────────────────────»
# «            ┌──┴───┴───┐└─────┬────┬────┘┌─────────┐        ┌────┐        »
# «q5_3 -> 143 ┤ Rz(-π/4) ├──────┤ √X ├─────┤ Rz(π/2) ├─■──────┤ √X ├──────■─»
# «            └──────────┘      └────┘     └─────────┘ │ ┌────┴────┴────┐ │ »
# «q5_0 -> 144 ─────────────────────────────────────────■─┤ Delay(6[dt]) ├─■─»
# «                                                       └──────────────┘   »
# «      c0: 3/══════════════════════════════════════════════════════════════»
# «                                                                          »
# «                                   ░ ┌────────────────┐┌───┐ »
# «q5_2 -> 136 ───────────────────────░─┤ Delay(144[dt]) ├┤ X ├─»
# «                                   ░ ├────────────────┤├───┤ »
# «q5_1 -> 142 ───────────────────────░─┤ Delay(144[dt]) ├┤ X ├─»
# «              ┌─────────┐   ┌────┐ ░ ├────────────────┤├───┤ »
# «q5_3 -> 143 ──┤ Rz(π/2) ├───┤ √X ├─░─┤ Delay(144[dt]) ├┤ X ├─»
# «            ┌─┴─────────┴──┐└────┘ ░ └──┬─────────┬───┘├───┴┐»
# «q5_0 -> 144 ┤ Delay(6[dt]) ├───────░────┤ Rz(π/2) ├────┤ √X ├»
# «            └──────────────┘       ░    └─────────┘    └────┘»
# «      c0: 3/═════════════════════════════════════════════════»
# «                                                             »
# «            ┌────────────────┐┌───┐┌────────────────┐ ░   ┌──────   »
# «q5_2 -> 136 ┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─░───┤       ──»
# «            ├────────────────┤├───┤├────────────────┤ ░   │         »
# «q5_1 -> 142 ┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─░───┤       ──»
# «            ├────────────────┤├───┤├────────────────┤ ░   │ If-0    »
# ...
# «q23_9 -> 110         ├───┤       ──────────────        ├──░──░─»
# «                     │   │                             │  ░  ░ »
# «q23_8 -> 111         ├───┤       ──────────────        ├──░──░─»
# «              ───────┘   └──╥───                ───────┘  ░  ░ »
# «                       ┌────╨─────┐                            »
# «       c0: 9/══════════╡ c0_6=0x1 ╞════════════════════════════»
# «                       └──────────┘                            »
# «             ┌────────────────┐┌───┐ ┌────────────────┐┌───┐┌────────────────┐»
# « q23_7 -> 98 ┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├»
# «             ├────────────────┤├───┤ ├────────────────┤├───┤├────────────────┤»
# «q23_0 -> 103 ┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├»
# «             ├────────────────┤├───┤ ├────────────────┤├───┤├────────────────┤»
# «q23_1 -> 104 ┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├»
# «             ├────────────────┤├───┤ ├────────────────┤├───┤├────────────────┤»
# «q23_2 -> 105 ┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├»
# «             ├────────────────┤├───┤ ├────────────────┤├───┤├────────────────┤»
# «q23_3 -> 106 ┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├»
# «             ├────────────────┤├───┤ ├────────────────┤├───┤├────────────────┤»
# «q23_4 -> 107 ┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├»
# «             ├────────────────┤├───┤ ├────────────────┤├───┤├────────────────┤»
# «q23_5 -> 108 ┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├»
# «             ├────────────────┤├───┤ ├────────────────┤├───┤├────────────────┤»
# «q23_6 -> 109 ┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├»
# «             ├────────────────┤├───┤ ├────────────────┤├───┤├────────────────┤»
# «q23_9 -> 110 ┤ Delay(144[dt]) ├┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├»
# «             └──┬─────────┬───┘├───┴┐└──┬─────────┬───┘└┬─┬┘└────────────────┘»
# «q23_8 -> 111 ───┤ Rz(π/2) ├────┤ √X ├───┤ Rz(π/2) ├─────┤M├───────────────────»
# «                └─────────┘    └────┘   └─────────┘     └╥┘                   »
# «       c0: 9/════════════════════════════════════════════╩════════════════════»
# «                                                         7                    »
# «              ░   ┌──────   ┌──────────┐ ───────┐  ░  ░    ┌─────────┐    »
# « q23_7 -> 98 ─░───┤       ──┤ Rz(-π/2) ├        ├──░──░────┤ Rz(π/2) ├────»
# «              ░   │         └──────────┘        │  ░  ░ ┌──┴─────────┴───┐»
# «q23_0 -> 103 ─░───┤       ──────────────        ├──░──░─┤ Delay(144[dt]) ├»
# «              ░   │                             │  ░  ░ ├────────────────┤»
# «q23_1 -> 104 ─░───┤       ──────────────        ├──░──░─┤ Delay(144[dt]) ├»
# «              ░   │                             │  ░  ░ ├────────────────┤»
# «q23_2 -> 105 ─░───┤       ──────────────        ├──░────┤ Delay(144[dt]) ├»
# «              ░   │                             │  ░  ░ ├────────────────┤»
# «q23_3 -> 106 ─░───┤       ──────────────        ├──░──░─┤ Delay(144[dt]) ├»
# «              ░   │ If-0                  End-0 │  ░  ░ ├────────────────┤»
# «q23_4 -> 107 ─░───┤       ──────────────        ├──░──░─┤ Delay(144[dt]) ├»
# «              ░   │                             │  ░  ░ ├────────────────┤»
# «q23_5 -> 108 ─░───┤       ──────────────        ├──░──░─┤ Delay(144[dt]) ├»
# «              ░   │                             │  ░  ░ ├────────────────┤»
# «q23_6 -> 109 ─░───┤       ──────────────        ├──░──░─┤ Delay(144[dt]) ├»
# «              ░   │                             │  ░  ░ ├────────────────┤»
# «q23_9 -> 110 ─░───┤       ──────────────        ├──░──░─┤ Delay(144[dt]) ├»
# «              ░   │                             │  ░  ░ ├────────────────┤»
# «q23_8 -> 111 ─░───┤       ──────────────        ├──░──░─┤ Delay(144[dt]) ├»
# «              ░   └──╥───                ───────┘  ░  ░ └────────────────┘»
# «                ┌────╨─────┐                                              »
# «       c0: 9/═══╡ c0_7=0x1 ╞══════════════════════════════════════════════»
# «                └──────────┘                                              »
# «             ┌────┐   ┌─────────┐                           ┌─┐ ░  ░
# « q23_7 -> 98 ┤ √X ├───┤ Rz(π/2) ├───────────────────────────┤M├─░──░─
# «             ├───┬┘┌──┴─────────┴───┐┌───┐┌────────────────┐└╥┘ ░  ░
# «q23_0 -> 103 ┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─╫──░──░─
# «             ├───┤ ├────────────────┤├───┤├────────────────┤ ║  ░  ░
# «q23_1 -> 104 ┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─╫──░──░─
# «             ├───┤ ├────────────────┤├───┤├────────────────┤ ║  ░  ░
# «q23_2 -> 105 ┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─╫─────░─
# «             ├───┤ ├────────────────┤├───┤├────────────────┤ ║  ░  ░
# «q23_3 -> 106 ┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─╫──░──░─
# «             ├───┤ ├────────────────┤├───┤├────────────────┤ ║  ░  ░
# «q23_4 -> 107 ┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─╫──░──░─
# «             ├───┤ ├────────────────┤├───┤├────────────────┤ ║  ░  ░
# «q23_5 -> 108 ┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─╫──░──░─
# «             ├───┤ ├────────────────┤├───┤├────────────────┤ ║  ░  ░
# «q23_6 -> 109 ┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─╫──░──░─
# «             ├───┤ ├────────────────┤├───┤├────────────────┤ ║  ░  ░
# «q23_9 -> 110 ┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─╫──░──░─
# «             ├───┤ ├────────────────┤├───┤├────────────────┤ ║  ░  ░
# «q23_8 -> 111 ┤ X ├─┤ Delay(320[dt]) ├┤ X ├┤ Delay(144[dt]) ├─╫──░──░─
# «             └───┘ └────────────────┘└───┘└────────────────┘ ║  ░  ░
# «       c0: 9/════════════════════════════════════════════════╩═══════
# «                                                             8
# transpiled normalized cirq depth: 216
# 4. Sampler is called correctly
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 53, 0.207
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 57, 0.144, 9.667
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.028, 24.392, 1.404 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.699, 0.694
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 65, 0.197
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 70, 0.142, 11.667
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.039, 13.374, 1.381 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.566, 0.563
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 78, 0.188
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 82, 0.13, 12.333
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.054, 13.799, 1.495 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.432, 0.43
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 92, 0.18
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 97, 0.127, 14.333
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.072, 14.12, 1.498 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.303, 0.301
#
# ... execution complete at Aug 11, 2025 16:04:01 UTC in 5317.114 secs
#
# Sample Circuit:
#       ┌───┐ ░                              ░ ┌───┐┌─┐                        »
# q8_0: ┤ H ├─░─────────────────────────■────░─┤ H ├┤M├────────────────────────»
#       ├───┤ ░                         │    ░ └───┘└╥┘  ┌──────   ┌──────────┐»
# q8_1: ┤ H ├─░──────────────────■──────┼────░───────╫───┤ If-0  ──┤ Rz(-π/2) ├»
#       ├───┤ ░                  │      │    ░       ║   └──╥───   └──────────┘»
# q8_2: ┤ H ├─░───────────■──────┼──────┼────░───────╫──────╫──────────────────»
#       ├───┤ ░           │      │      │    ░       ║      ║                  »
# q8_3: ┤ H ├─░────■──────┼──────┼──────┼────░───────╫──────╫──────────────────»
#       ├───┤ ░ ┌──┴──┐┌──┴──┐┌──┴──┐┌──┴──┐ ░       ║      ║                  »
# q8_4: ┤ X ├─░─┤ U^1 ├┤ U^2 ├┤ U^4 ├┤ U^8 ├─░───────╫──────╫──────────────────»
#       └───┘ ░ └─────┘└─────┘└─────┘└─────┘ ░       ║ ┌────╨─────┐            »
# c0: 4/═════════════════════════════════════════════╩═╡ c0_0=0x1 ╞════════════»
#                                                    0 └──────────┘            »
# «                                                                          »
# «q8_0: ────────────────────────────────────────────────────────────────────»
# «       ───────┐                                                           »
# «q8_1:   End-0 ├───────────────────────────────────────────────────────────»
# «       ───────┘   ┌──────   ┌──────────┐ ───────┐                         »
# «q8_2: ────────────┤ If-0  ──┤ Rz(-π/4) ├  End-0 ├─────────────────────────»
# «                  └──╥───   └──────────┘ ───────┘   ┌──────   ┌──────────┐»
# «q8_3: ───────────────╫──────────────────────────────┤ If-0  ──┤ Rz(-π/8) ├»
# «                     ║                              └──╥───   └──────────┘»
# «q8_4: ───────────────╫─────────────────────────────────╫──────────────────»
# «                ┌────╨─────┐                      ┌────╨─────┐            »
# «c0: 4/══════════╡ c0_0=0x1 ╞══════════════════════╡ c0_0=0x1 ╞════════════»
# «                └──────────┘                      └──────────┘            »
# «                 ░                                                       »
# «q8_0: ───────────░───────────────────────────────────────────────────────»
# «                 ░ ┌───┐┌─┐                                              »
# «q8_1: ───────────░─┤ H ├┤M├──────────────────────────────────────────────»
# «                 ░ └───┘└╥┘  ┌──────   ┌──────────┐ ───────┐             »
# «q8_2: ───────────░───────╫───┤ If-0  ──┤ Rz(-π/2) ├  End-0 ├─────────────»
# «       ───────┐  ░       ║   └──╥───   └──────────┘ ───────┘   ┌──────   »
# «q8_3:   End-0 ├──░───────╫──────╫──────────────────────────────┤ If-0  ──»
# «       ───────┘  ░       ║      ║                              └──╥───   »
# «q8_4: ───────────────────╫──────╫─────────────────────────────────╫──────»
# «                         ║ ┌────╨─────┐                      ┌────╨─────┐»
# «c0: 4/═══════════════════╩═╡ c0_1=0x1 ╞══════════════════════╡ c0_1=0x1 ╞»
# «                         1 └──────────┘                      └──────────┘»
# «                             ░                                            ░ »
# «q8_0: ───────────────────────░────────────────────────────────────────────░─»
# «                             ░                                            ░ »
# «q8_1: ───────────────────────░────────────────────────────────────────────░─»
# «                             ░ ┌───┐┌─┐                                   ░ »
# «q8_2: ───────────────────────░─┤ H ├┤M├───────────────────────────────────░─»
# «      ┌──────────┐ ───────┐  ░ └───┘└╥┘  ┌──────   ┌──────────┐ ───────┐  ░ »
# «q8_3: ┤ Rz(-π/4) ├  End-0 ├──░───────╫───┤ If-0  ──┤ Rz(-π/2) ├  End-0 ├──░─»
# «      └──────────┘ ───────┘  ░       ║   └──╥───   └──────────┘ ───────┘  ░ »
# «q8_4: ───────────────────────────────╫──────╫───────────────────────────────»
# «                                     ║ ┌────╨─────┐                         »
# «c0: 4/═══════════════════════════════╩═╡ c0_2=0x1 ╞═════════════════════════»
# «                                     2 └──────────┘                         »
# «               ░  ░
# «q8_0: ─────────░──░─
# «               ░  ░
# «q8_1: ─────────░──░─
# «               ░  ░
# «q8_2: ─────────░──░─
# «      ┌───┐┌─┐ ░  ░
# «q8_3: ┤ H ├┤M├─░──░─
# «      └───┘└╥┘ ░  ░
# «q8_4: ──────╫─────░─
# «            ║     ░
# «c0: 4/══════╩═══════
# «            3
#
# Phase Operator 'U' =
#    ┌────────┐
# q: ┤ P(π/2) ├
#    └────────┘
#
# Dynamic Inverse QFT Circuit =
#              ┌───┐┌─┐                                                          »
# q_dyn_inv_0: ┤ H ├┤M├──────────────────────────────────────────────────────────»
#              └───┘└╥┘  ┌──────   ┌──────────┐ ───────┐                         »
# q_dyn_inv_1: ──────╫───┤ If-0  ──┤ Rz(-π/2) ├  End-0 ├─────────────────────────»
#                    ║   └──╥───   └──────────┘ ───────┘   ┌──────   ┌──────────┐»
# q_dyn_inv_2: ──────╫──────╫──────────────────────────────┤ If-0  ──┤ Rz(-π/4) ├»
#                    ║      ║                              └──╥───   └──────────┘»
# q_dyn_inv_3: ──────╫──────╫─────────────────────────────────╫──────────────────»
#                    ║ ┌────╨─────┐                      ┌────╨─────┐            »
#        c0: 4/══════╩═╡ c0_0=0x1 ╞══════════════════════╡ c0_0=0x1 ╞════════════»
#                    0 └──────────┘                      └──────────┘            »
# «                                                          ░         »
# «q_dyn_inv_0: ─────────────────────────────────────────────░─────────»
# «                                                          ░ ┌───┐┌─┐»
# «q_dyn_inv_1: ─────────────────────────────────────────────░─┤ H ├┤M├»
# «              ───────┐                                    ░ └───┘└╥┘»
# «q_dyn_inv_2:   End-0 ├────────────────────────────────────░───────╫─»
# «              ───────┘   ┌──────   ┌──────────┐ ───────┐  ░       ║ »
# «q_dyn_inv_3: ────────────┤ If-0  ──┤ Rz(-π/8) ├  End-0 ├──░───────╫─»
# «                         └──╥───   └──────────┘ ───────┘  ░       ║ »
# «                       ┌────╨─────┐                               ║ »
# «       c0: 4/══════════╡ c0_0=0x1 ╞═══════════════════════════════╩═»
# «                       └──────────┘                               1 »
# «                                                                       »
# «q_dyn_inv_0: ──────────────────────────────────────────────────────────»
# «                                                                       »
# «q_dyn_inv_1: ──────────────────────────────────────────────────────────»
# «               ┌──────   ┌──────────┐ ───────┐                         »
# «q_dyn_inv_2: ──┤ If-0  ──┤ Rz(-π/2) ├  End-0 ├─────────────────────────»
# «               └──╥───   └──────────┘ ───────┘   ┌──────   ┌──────────┐»
# «q_dyn_inv_3: ─────╫──────────────────────────────┤ If-0  ──┤ Rz(-π/4) ├»
# «                  ║                              └──╥───   └──────────┘»
# «             ┌────╨─────┐                      ┌────╨─────┐            »
# «       c0: 4/╡ c0_1=0x1 ╞══════════════════════╡ c0_1=0x1 ╞════════════»
# «             └──────────┘                      └──────────┘            »
# «                        ░                                            ░      »
# «q_dyn_inv_0: ───────────░────────────────────────────────────────────░──────»
# «                        ░                                            ░      »
# «q_dyn_inv_1: ───────────░────────────────────────────────────────────░──────»
# «                        ░ ┌───┐┌─┐                                   ░      »
# «q_dyn_inv_2: ───────────░─┤ H ├┤M├───────────────────────────────────░──────»
# «              ───────┐  ░ └───┘└╥┘  ┌──────   ┌──────────┐ ───────┐  ░ ┌───┐»
# «q_dyn_inv_3:   End-0 ├──░───────╫───┤ If-0  ──┤ Rz(-π/2) ├  End-0 ├──░─┤ H ├»
# «              ───────┘  ░       ║   └──╥───   └──────────┘ ───────┘  ░ └───┘»
# «                                ║ ┌────╨─────┐                              »
# «       c0: 4/═══════════════════╩═╡ c0_2=0x1 ╞══════════════════════════════»
# «                                2 └──────────┘                              »
# «                 ░
# «q_dyn_inv_0: ────░─
# «                 ░
# «q_dyn_inv_1: ────░─
# «                 ░
# «q_dyn_inv_2: ────░─
# «             ┌─┐ ░
# «q_dyn_inv_3: ┤M├─░─
# «             └╥┘ ░
# «       c0: 4/═╩════
# «              3

# %% [markdown]
# ### HHL Linear Solver

# %%
import sys
sys.path.insert(1, "hhl/qiskit")
import hhl_benchmark

hhl_benchmark.verbose=False

hhl_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1, use_best_widths=True,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Amplitude Estimation

# %%
import sys
sys.path.insert(1, "amplitude-estimation/qiskit")
import ae_benchmark
ae_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Monte Carlo

# %%
import sys
sys.path.insert(1, "monte-carlo/qiskit")
import mc_benchmark
mc_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Hamiltonian Simulation - Method 1

# %%
import sys
sys.path.insert(1, "hamiltonian-simulation")
import hamiltonian_simulation_benchmark
hamiltonian_simulation_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### VQE - Method 1

# %%
import sys
sys.path.insert(1, "vqe/qiskit")
import vqe_benchmark
vqe_num_shots=4098
vqe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=vqe_num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Shor - Method 1

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Shor - Method 2

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Close session
# IMPORTANT: This cell is provided as a way to close an active session if for some reason the benchmarks abort abnormally.
# If so, execute the close_session function manually to terminate an open session. Normally, this is done automatically.

# %%
import sys
sys.path.insert(1, "_common")
import execute as ex

ex.close_session()

# %% [markdown]
# ### Combined Benchmark Results

# %%
import sys
sys.path.insert(1, "_common")
import metrics

# metrics.depth_base = 2
# metrics.QV = 0
# apps = [ "Hidden Shift", "Grover's Search", "Quantum Fourier Transform (1)", "Hamiltonian Simulation" ]
# backend_id='qasm_simulator'

metrics.plot_all_app_metrics(backend_id, do_all_plots=False, include_apps=None)
